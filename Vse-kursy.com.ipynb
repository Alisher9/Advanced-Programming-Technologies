# %%
import requests
import re # regular expressions
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
CHROME_DRIVER_PATH = r'C:\Users\FLOX\ChromeDriver\chromedriver.exe'
driver = webdriver.Chrome(CHROME_DRIVER_PATH)

# %%
# step 1
URL = 'https://vse-kursy.com/onlain/'

# %%
driver.get(URL)

# %%
content = driver.page_source
soup = BeautifulSoup(content)

# %%
names_courses = []
description = []

for block in soup.findAll('div', attrs={'class':'listco'}):
    name_str = block.find('div', attrs={'class': 'listcot col-md-9 col-sm-9 col-xs-9'}).text
    desc = block.find('div', attrs={'class': 'listcotdown'}).text
   
    names_courses.append(name_str)
    
    names.append(name_str)
    description.append(desc)

# %%
data = {
    'Courses Name': names_courses,
    'Description': desc
}
df = pd.DataFrame(data)

# %%
df
# Out:
#                                          Courses Name         Description
# 0   Флористика с нуля - профессиональное обучение ...  По набору8 месяцев
# 1   Дизайн жилых интерьеров - обучение по специаль...  По набору8 месяцев
# 2   Курс обучения Профессия Data Scientist: анализ...  По набору8 месяцев
# 3   Профессия SEO-специалист - обучение с возможно...  По набору8 месяцев
# 4   Дизайнер-фрилансер (от заявки клиента до оплат...  По набору8 месяцев
# 5   Профессия Режиссер монтажа - курс обученияВы с...  По набору8 месяцев
# 6   Управление персоналом (HR) - программа обучени...  По набору8 месяцев
# 7   Разработчик игр на Unity - курс обучения профе...  По набору8 месяцев
# 8   Обучение на профессию Event-менеджерКурс отлич...  По набору8 месяцев
# 9   Курс обучения на профессию Motion-дизайнерВы с...  По набору8 месяцев
# 10  Профессия 3D аниматор - обучение с возможность...  По набору8 месяцев
# 11  Курс обучения на HR-менеджера с нуляУзнаете о ...  По набору8 месяцев
# ...
